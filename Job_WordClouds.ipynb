# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
# Deleting stopwords and punctucation is key for proper bigram creation
responsibilities = 'Execute complex data science data engineering projects that significant impact Bosch global businessShare knowledge clearly articulating results ideas customers managers key decision makers Collaborate product engineering marketing teams across many business domains (automotive industrial internet things) translate business needs intechnical solutions Select apply appropriate statistical machine learning computing methods large-scale high-dimensional data Develop analytic methods decision support various businesses Stay current latest research technology communicate your knowledge throughout enterprise Take responsibility fpreparing data fanalysis review data preparation/ETL code provide critical feedback issues data integrity Contribute patent portfolio Up 10% travel may required We leverage unique diverse deep data set We just about every sort data can imagine -- text network analysis image recognition surprised what connections weve found between different data sources finding these connections communicating team well integrating them models own model multiple models whether building country-level credit model scratch integrating new data sources inour existing underwriting models work machine learning features products such Recommendations Audience Discovery VisitScoring Automated Optimization build Prediction Services that rely offline online data integration appropriate feature selection model training build systems services using batch stream processing spanning technologies such Hadoop Samza Spark languages such Java Scala understand scalability performance tradeoffs among various ML techniques appropriately build ML systems we move prototype production coordinate work applicatiproduct teams implement Machine Learning features end throughout platform Work multi-disciplined team take full ownership turning discoveries ideas inmachine learning models use models output create improve products four customers preferably short development cyclesResearch & Development improve customers’ experience using vast amount data Actively contribute taking Data Science at Bookingcom next levelTransform large complex datasets inpragmatic actionable insights Leverage data identify quantify influence tangible business gain Ability see beyond numbers voice data when communicating decision makers product owners team leaderscapacity thrive fast-paced environment adapt quickly take ownership your work Challenge ideas methods while working together talented highly skilled team membersWere looking fa data junkie who dreams about builds cool data projects during their spare time is obsessed data quality If that describes you team build deploy online analytical models that would solve particular problems within various business functions including but not limited to marketing growth customer success finance platform infrastructure name few also build data architecture infrastructure applications tools data-integration experimentation quality modeling etc build prototype few days deploy your first model couple weeks build maintain an experimentaton platform Provides analytic support strategic thought partnership Direct Marketing team ideal candidate ability tell stories data communicate effectively instill confidence recommendations motivate stakeholders take actionBuilds recommendations synthesizing data multiple sources developing assumptions needed drive business insights strategy development Completes analytics projects requiring collaboration business stakeholders Builds validates publishes analytics reports dashboards fbusinessvDelivers key insights interpretation recommendation contributes development hypotheses actions presents them management team Partners Marketing leaders identify key customer segments contributes executive various campaigns initiatives Develops new better analytics approaches solve questions creative way Develop algorithms contribute research area advanced analytics continuous glucose dataUse techniques supervised unsupervised machine learning statistical analysis predictive modeling build knowledge glucose behavior Test algorithms real data simulationsAnalyze data clinical trialsDefine data requirements fmachine learning measurement testing evaluation activities Design build integrate solutions return label data several pipelines Script write queries call internal external APIs gather ingest label data at scaleCreate reporting dashboards Implement security data protection policies procedures Leverage advanced analytical techniques programming languages mine through massive data sets isolate patterns customer purchase behavior store performance competitive pricing schemes (predictive modeling clustering design experiments etc)Work team members influence strategic decisions create accurate financial forecasts based deep customer behavianalyses tangible recommendations optimize customer acquisition retention lifetime value Utilize exceptional communication skills present findings across business effectively translating complex data analysis inclear insights opportunities tangible business recommendations;Develop reports dashboards build compelling data visualizations that effectively measure track quantify changes customer behavispend patterns Contribute complex long-term projects initial scoping through full executitraining inputs variety cross-functional teams (IT Merch ising Marketing)Collaborate data science team an expert business providing directibest leverage advanced modeling techniques machine learning algorithms achieve strategic objectives business goals Display deep intellectual curiosity creativity commitment learning solve critical business problems push boundary capabilities'
requirements = 'Degree Level PhD MS 1 work Majors Computer Science Statistics related quantitative technical fieldsbackground statistics machine learning big data processing Proven programming 1 following Python Java Scala R C++ Demonstrated ability work both independently team environment analytical problem solving skills Enthusiastic about learning new tools & technologies Excellent communication skills working big data tool chains Hadoop Spark ecosystems neural networks deep learning methods 3+ years data science role equivalent position Masters PhD quantitative field Fluent Python packages related machine learning building fraud credit risk models Expertise NLP network analysis geospatial analysis maintaining data science models production environment havefundamentals Computer Science especially algorithms datastructures an expert one Java Scala Python C++ comfortable working JavaScript have practical machine learning that allows develop sound approaches for problems contextual decision making clustering content targeting optimization ranking prediction classification have distributed systems adapt machine learning approaches from simulation prototypes production particular have hands-experience some following Hadoop Samza Spark HBase SQL DBs have 3 5 years doing looking for your next big challenge Minimum two years work Masters PhD equivalent quantitative field Computer Science Mathematics Engineering Artificial Intelligence etc Excellent English communication skills ability convey your message team members other stakeholders Prior few following models Logistic Regression Support Vector Machines Deep Neural Networks Hidden Markov Models Conditional Random Fields Game Theory Mechanism DesignLatent Dirichlet Allocation one scripting language R Octave one programming language Python Perl C/C++ Java Exposure SQL relational databases implementing real-world Recommender Ranking system Worked Hadoop Ecosystem Implemented multi-core/distributed software preferably Linux environment Minimum 3 years role solving real problems using data mining techniques statistical rigour Masters PhD equivalent quantitative field computer science physics mathematics engineering bioinformatics etctechnical skills regarding data analysis statistics programmingworking knowledge of Python Hadoop SQL R Excellent communication skills ability convey complex analysis results clearly conviction all levels stakeholders Developed machine learning models deployed these models online Built real-time data flows stood up distributed data flow infrastructure Expert knowledge either one Python Java C C++ Passionate about working large datasetscommunication skills understand translate business problems into technical solutions also clearly communicate innovations possibilities PhD CS related quantitative field 3+ years MS CS related quantitative field 6+ years machine learning 3-7 years data analysis preferably Direct Marketingknowledge SQL SASanalytical problem solving skills Tableau preferred similar BI tools A/B testing setup evaluation preferred Outstanding communication skills both technical non-technical colleagues vPrefer candidates Finance Mortgage Banking Must be working towards Masters PhD Computer Science Biomedical Engineering closely related discipline GPA 30 higher   Hands-experience creating an algorithm based data proven passion for generating insights from data Knowledge statistical methods generally particularly areas modeling programming database tools data signal processing programming languages R Python Matlab Familiarity visualization software techniques Capable conducting independent research Excited by motivated by hard technical challenges Results-driven self-motivated self-starter Excellent written verbal communications skills proven ability communicate technical information cross-functional audience xCandidates must either be local San Diego County willing able secure housing San Diego area if offered internship their own expense position will be on-site our Corporate HDQ offices Sorrento Valley Bachelors degree Computer Science Information Systems related field 5+ years software development iPython API consumption using RESTful web services JSON AWS Git ETL data mining machine learning Exposure Big Data technologies Hadoop Amazon EMR Agile vAbility work independently well team environment Bachelors degree economics statistics math related business field Master’s preferred Minimum 1 years analytics statistics capacity 2 years ideal statistical programming languages required R must Python SAS building large data sets across disparate sources required SQL Hive Hadoop Desire learn new analytic data manipulation techniques become an local expert Advanced presentation skills required PowerPoint Adobe Photoshop/Illustrator R packages pricing merchandising marketing retail industry strongly preferred Ability think conceptually creatively about problems solutionsinterpersonal communication skills verbal written required due nature level interaction senior management Demonstrated ability prioritize workload ability manage multiple projects while meeting deadlines'

def bigram(text):
    count = 0
    text_bigram = ''
    for letter in text:
        if letter != ' ':
            text_bigram += letter
        else:
            count += 1
            if count % 2 == 0:
                text_bigram += 'x'
            else:
                text_bigram += letter
    return text_bigram

responsibilities_bigram = bigram(responsibilities)
requirements_bigram = bigram(requirements)

# %%
# Single Cloud
wordcloud = WordCloud().generate(responsibilities)
print('Responsibilities Single Cloud:')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show();

# Bigram Cloud
wordcloud_bigrams = WordCloud().generate(responsibilities_bigram)
print('Responsibilities Bigrams:')
plt.imshow(wordcloud_bigrams, interpolation='bilinear')
plt.axis("off")
plt.show();
# Out:
# Responsibilities Single Cloud:
# Responsibilities Bigrams:

# %%
# Single Cloud
wordcloud = WordCloud().generate(requirements)
print('Requirements Single Cloud:')
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show();

# Bigram Cloud
wordcloud_bigrams = WordCloud().generate(requirements_bigram)
print('Requirements Bigrams:')
plt.imshow(wordcloud_bigrams, interpolation='bilinear')
plt.axis("off")
plt.show();
# Out:
# Requirements Single Cloud:
# Requirements Bigrams:
